# %%
import pandas as pd #Library for importing dataframes
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython import get_ipython
import warnings
warnings.filterwarnings ('ignore')

# %%
online_retail =pd.read_csv("home/george/Documents/data analysis/online retail.csv")

# %%
online_retail1.head(5)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  1/12/2009 7:45   6.95      13085.0  United Kingdom
# 1  1/12/2009 7:45   6.75      13085.0  United Kingdom
# 2  1/12/2009 7:45   6.75      13085.0  United Kingdom
# 3  1/12/2009 7:45   2.10      13085.0  United Kingdom
# 4  1/12/2009 7:45   1.25      13085.0  United Kingdom

# %%
online_retail1
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1048570  580501     23284        DOORMAT KEEP CALM AND COME IN         2
# 1048571  580501     22507         MEMO BOARD RETROSPOT  DESIGN         3
# 1048572  580502     22469                HEART OF WICKER SMALL         3
# 1048573  580502     23489                VINTAGE BELLS GARLAND         2
# 1048574  580502     23046    PAPER LANTERN 9 POINT DELUXE STAR         1
#
#              InvoiceDate  Price  Customer ID         Country
# ...

# %%
online_retail1.tail(5)
# Out:
#         Invoice StockCode                        Description  Quantity  \
# 1048570  580501     23284      DOORMAT KEEP CALM AND COME IN         2
# 1048571  580501     22507       MEMO BOARD RETROSPOT  DESIGN         3
# 1048572  580502     22469              HEART OF WICKER SMALL         3
# 1048573  580502     23489              VINTAGE BELLS GARLAND         2
# 1048574  580502     23046  PAPER LANTERN 9 POINT DELUXE STAR         1
#
#              InvoiceDate  Price  Customer ID         Country
# 1048570  4/12/2011 13:00   8.25      14546.0  United Kingdom
# 1048571  4/12/2011 13:00   4.95      14546.0  United Kingdom
# 1048572  4/12/2011 13:15   1.65      16931.0  United Kingdom
# 1048573  4/12/2011 13:15   2.89      16931.0  United Kingdom
# 1048574  4/12/2011 13:15   6.65      16931.0  United Kingdom

# %%
online_retail1.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
online_retail1.shape
# Out:
# (1048575, 8)

# %%
online_retail1.duplicated().sum()
# Out:
# 34150

# %%
online_retail1.duplicated().head(5)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
online_data=online_retail1.drop_duplicates()

# %%
online_data
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1048570  580501     23284        DOORMAT KEEP CALM AND COME IN         2
# 1048571  580501     22507         MEMO BOARD RETROSPOT  DESIGN         3
# 1048572  580502     22469                HEART OF WICKER SMALL         3
# 1048573  580502     23489                VINTAGE BELLS GARLAND         2
# 1048574  580502     23046    PAPER LANTERN 9 POINT DELUXE STAR         1
#
#              InvoiceDate  Price  Customer ID         Country
# ...

# %%
online_data.duplicated().sum()
# Out:
# 0

# %%
online_data.shape
# Out:
# (1014425, 8)

# %%
online_data.isnull()
# Out:
#          Invoice  StockCode  Description  Quantity  InvoiceDate  Price  \
# 0          False      False        False     False        False  False
# 1          False      False        False     False        False  False
# 2          False      False        False     False        False  False
# 3          False      False        False     False        False  False
# 4          False      False        False     False        False  False
# ...          ...        ...          ...       ...          ...    ...
# 1048570    False      False        False     False        False  False
# 1048571    False      False        False     False        False  False
# 1048572    False      False        False     False        False  False
# 1048573    False      False        False     False        False  False
# 1048574    False      False        False     False        False  False
#
#          Customer ID  Country
# 0              False    False
# 1              False    False
# ...

# %%
online_data.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4265
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    228826
# Country             0
# dtype: int64

# %%
online_data=online_data.drop('Description', axis =1)

# %%
online_data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Quantity', 'InvoiceDate', 'Price',
#        'Customer ID', 'Country'],
#       dtype='object')

# %%
online_data.shape
# Out:
# (1014425, 7)

# %%
online_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1014425 entries, 0 to 1048574
# Data columns (total 7 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1014425 non-null  object
#  1   StockCode    1014425 non-null  object
#  2   Quantity     1014425 non-null  int64
#  3   InvoiceDate  1014425 non-null  object
#  4   Price        1014425 non-null  float64
#  5   Customer ID  785599 non-null   float64
#  6   Country      1014425 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 61.9+ MB

# %%
online_data.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.014425e+06  1.014425e+06  785599.000000
# mean   1.009725e+01  4.590115e+00   15313.078667
# std    1.352799e+02  1.215813e+02    1695.992802
# min   -7.421500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13963.000000
# 50%    3.000000e+00  2.100000e+00   15235.000000
# 75%    1.000000e+01  4.150000e+00   16788.000000
# max    7.421500e+04  3.897000e+04   18287.000000

# %%
online_data['InvoiceDate']=pd.to_datetime(online_data['InvoiceDate'])

# %%
online_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1014425 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1014425 non-null  object
#  1   StockCode    1014425 non-null  object
#  2   Quantity     1014425 non-null  int64
#  3   InvoiceDate  1014425 non-null  datetime64[ns]
#  4   Price        1014425 non-null  float64
#  5   Customer ID  785599 non-null   float64
#  6   Country      1014425 non-null  object
#  7   InvoiveDate  1014425 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 69.7+ MB

# %%
online_data.nunique()
# Out:
# Invoice        52961
# StockCode       5304
# Quantity        1048
# InvoiceDate    47046
# Price           2784
# Customer ID     5924
# Country           43
# InvoiveDate    47046
# dtype: int64

# %%
online_data

# %%
online_data['Year']=pd.DatetimeIndex(online_data['InvoiceDate']).year

# %%
online_data.head(5)
# Out:
#   Invoice StockCode  Quantity         InvoiceDate  Price  Customer ID  \
# 0  489434     85048        12 2009-01-12 07:45:00   6.95      13085.0
# 1  489434    79323P        12 2009-01-12 07:45:00   6.75      13085.0
# 2  489434    79323W        12 2009-01-12 07:45:00   6.75      13085.0
# 3  489434     22041        48 2009-01-12 07:45:00   2.10      13085.0
# 4  489434     21232        24 2009-01-12 07:45:00   1.25      13085.0
#
#           Country         InvoiveDate  Year
# 0  United Kingdom 2009-01-12 07:45:00  2009
# 1  United Kingdom 2009-01-12 07:45:00  2009
# 2  United Kingdom 2009-01-12 07:45:00  2009
# 3  United Kingdom 2009-01-12 07:45:00  2009
# 4  United Kingdom 2009-01-12 07:45:00  2009
